# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/Pavel/Downloads/country_vaccinations.csv')
a=df.daily_vaccinations.mean()

# %%
df
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Algeria      DZA  2021-01-29                 0.0                NaN
# 1     Algeria      DZA  2021-01-30                30.0                NaN
# 2     Andorra      AND  2021-01-25               576.0              576.0
# 3     Andorra      AND  2021-01-26                 NaN                NaN
# 4     Andorra      AND  2021-01-27                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 2600    Wales      NaN  2021-02-04            524677.0           523042.0
# 2601    Wales      NaN  2021-02-05            559468.0           556997.0
# 2602    Wales      NaN  2021-02-06            592228.0           589622.0
# 2603    Wales      NaN  2021-02-07            606768.0           603976.0
# 2604    Wales      NaN  2021-02-08            632251.0           628760.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
df.fillna('No information')
# Out:
#       country        iso_code        date total_vaccinations  \
# 0     Algeria             DZA  2021-01-29                  0
# 1     Algeria             DZA  2021-01-30                 30
# 2     Andorra             AND  2021-01-25                576
# 3     Andorra             AND  2021-01-26     No information
# 4     Andorra             AND  2021-01-27     No information
# ...       ...             ...         ...                ...
# 2600    Wales  No information  2021-02-04             524677
# 2601    Wales  No information  2021-02-05             559468
# 2602    Wales  No information  2021-02-06             592228
# 2603    Wales  No information  2021-02-07             606768
# 2604    Wales  No information  2021-02-08             632251
#
#      people_vaccinated people_fully_vaccinated daily_vaccinations_raw  \
# 0       No information          No information         No information
# 1       No information          No information                     30
# ...

# %%
# %%timeit
list(df['country'])[1000]
# Out:
# 380 µs ± 3.11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df[df.country=='Israel'][['date','total_vaccinations']].sort_values(by='date',ascending=False).iloc[0]['total_vaccinations']
# Out:
# 4347206.0

# %%
df=df.sort_values(by='total_vaccinations',ascending=False)
df
df[df.people_vaccinated_per_hundred==df.people_vaccinated_per_hundred.max()][['date','country','people_vaccinated_per_hundred']]
# Out:
#            date country  people_vaccinated_per_hundred
# 796  2021-01-28  Israel                          32.92
# 795  2021-01-27  Israel                          32.92

# %%
countries={}
k=0
for country in df.country:
    if country not in countries:
        countries[country]=1
    countries[country]+=1

# %%
countries
# Out:
# {'Argentina': 32,
#  'Austria': 12,
#  'Bahrain': 30,
#  'Belgium': 32,
#  'Bermuda': 15,
#  'Brazil': 14,
#  'Bulgaria': 31,
#  'Canada': 22,
#  'Chile': 36,
#  'China': 45,
#  'Costa Rica': 34,
#  'Croatia': 28,
#  'Cyprus': 18,
#  'Czechia': 33,
#  'Denmark': 33,
#  'Ecuador': 9,
#  'England': 40,
#  'Estonia': 33,
#  'Finland': 30,
#  'France': 41,
#  'Germany': 33,
#  'Gibraltar': 19,
#  'Greece': 33,
#  'Hungary': 32,
#  'Iceland': 30,
#  'India': 14,
#  'Indonesia': 18,
#  'Ireland': 29,
#  'Isle of Man': 9,
#  'Israel': 42,
#  'Italy': 34,
#  'Kuwait': 2,
#  'Latvia': 32,
#  'Lithuania': 33,
#  'Luxembourg': 30,
#  'Malta': 32,
#  'Mexico': 36,
#  'Myanmar': 3,
#  'Netherlands': 24,
#  'Northern Cyprus': 10,
#  'Northern Ireland': 47,
#  'Norway': 33,
#  'Oman': 32,
#  'Panama': 7,
#  'Poland': 32,
#  'Portugal': 33,
#  'Romania': 33,
#  'Russia': 31,
#  'Saudi Arabia': 13,
#  'Scotland': 46,
#  'Serbia': 21,
#  'Seychelles': 20,
#  'Singapore': 19,
#  'Slovakia': 25,
# ...

# %%
b=[]
for key in countries:
    b.append(key)

# %%
b
# Out:
# ['Argentina',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Bermuda',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Ecuador',
#  'England',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Kuwait',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Mexico',
#  'Myanmar',
#  'Netherlands',
#  'Northern Cyprus',
#  'Northern Ireland',
#  'Norway',
#  'Oman',
#  'Panama',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Saudi Arabia',
#  'Scotland',
#  'Serbia',
#  'Seychelles',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Wales']

# %%
df
# Out:
#         country        date  total_vaccinations  people_vaccinated  \
# 0     Argentina  2020-12-29               700.0                NaN
# 1     Argentina  2020-12-30                 NaN                NaN
# 2     Argentina  2020-12-31             32013.0                NaN
# 3     Argentina  2021-01-01                 NaN                NaN
# 4     Argentina  2021-01-02                 NaN                NaN
# ...         ...         ...                 ...                ...
# 1671      Wales  2021-01-23            265054.0           264538.0
# 1672      Wales  2021-01-24            271376.0           270833.0
# 1673      Wales  2021-01-25            290147.0           289566.0
# 1674      Wales  2021-01-26            312944.0           312305.0
# 1675      Wales  2021-01-27            336745.0           336071.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# ...

# %%
df[df.vaccines=='Sputnik V']['country'].value_counts()
# Out:
# Argentina    31
# Russia       30
# Name: country, dtype: int64

# %%
df[df.vaccines=='Pfizer/BioNTech']['country'].value_counts()
# Out:
# France          40
# Chile           35
# Mexico          35
# Switzerland     33
# Costa Rica      33
# Italy           33
# Estonia         32
# Portugal        32
# Norway          32
# Romania         32
# Greece          32
# Oman            31
# Latvia          31
# Hungary         31
# Malta           31
# Poland          31
# Finland         29
# Luxembourg      29
# Sweden          29
# Ireland         28
# Croatia         27
# Slovenia        25
# Slovakia        24
# Gibraltar       18
# Singapore       18
# Cyprus          17
# Bermuda         14
# Saudi Arabia    12
# Austria         11
# Isle of Man      8
# Ecuador          8
# Panama           6
# Kuwait           1
# Name: country, dtype: int64

# %%
df[(df.country=='Russia')&(df.date>='2021-01-01')][['total_vaccinations','date','vaccines']]
# Out:
#       total_vaccinations        date   vaccines
# 1250                 NaN  2021-01-01  Sputnik V
# 1251            800000.0  2021-01-02  Sputnik V
# 1252                 NaN  2021-01-03  Sputnik V
# 1253                 NaN  2021-01-04  Sputnik V
# 1254                 NaN  2021-01-05  Sputnik V
# 1255                 NaN  2021-01-06  Sputnik V
# 1256                 NaN  2021-01-07  Sputnik V
# 1257                 NaN  2021-01-08  Sputnik V
# 1258                 NaN  2021-01-09  Sputnik V
# 1259                 NaN  2021-01-10  Sputnik V
# 1260                 NaN  2021-01-11  Sputnik V
# 1261                 NaN  2021-01-12  Sputnik V
# 1262           1000000.0  2021-01-13  Sputnik V

# %%
df[(df.country=='Russia')&(df.date=='2021-01-13')]['total_vaccinations']
# Out:
# 1262    1000000.0
# Name: total_vaccinations, dtype: float64

# %%
df[(df.country=='Russia')&(df.date=='2021-01-02')]['total_vaccinations']
# Out:
# 1251    800000.0
# Name: total_vaccinations, dtype: float64

# %%
df[df.date=='2021-01-27']['total_vaccinations'].sum()
# Out:
# 86754432.0

# %%
df
# Out:
#                    country iso_code        date  total_vaccinations  \
# 1629         United States      USA  2021-01-27          24652634.0
# 1627         United States      USA  2021-01-25          22734243.0
# 1626         United States      USA  2021-01-24          21848655.0
# 1628         United States      USA  2021-01-26          23540994.0
# 258                  China      CHN  2021-01-27          22767000.0
# ...                    ...      ...         ...                 ...
# 1512                Turkey      TUR  2021-01-13                 0.0
# 1528  United Arab Emirates      ARE  2021-01-05            826301.0
# 1552        United Kingdom      GBR  2020-12-20            669674.0
# 1591         United States      USA  2020-12-20            556208.0
# 1630                 Wales      NaN  2020-12-13              8181.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1629         20687970.0                3801053.0               1111640.0
# ...

# %%
df.groupby('country').daily_vaccinations.max().sort_values(ascending=False)
# Out:
# country
# China             1916190.0
# United States     1489333.0
# United Kingdom     445128.0
# England            376532.0
# India              353235.0
#                     ...
# Algeria                30.0
# Greenland               NaN
# Guernsey                NaN
# Liechtenstein           NaN
# Saint Helena            NaN
# Name: daily_vaccinations, Length: 80, dtype: float64

# %%
df[(df.daily_vaccinations==df.daily_vaccinations.max())&(df.country=='United States')][['date','daily_vaccinations']]
# Out:
#             date  daily_vaccinations
# 1629  2021-01-27           1161050.0

# %%
df[df.daily_vaccinations_per_million>2500].sort_values(by='daily_vaccinations_per_million',ascending=False)
# Out:
#                country iso_code        date  total_vaccinations  \
# 582          Gibraltar      GIB  2021-01-12              2501.0
# 581          Gibraltar      GIB  2021-01-11              1445.0
# 583          Gibraltar      GIB  2021-01-13                 NaN
# 584          Gibraltar      GIB  2021-01-14                 NaN
# 585          Gibraltar      GIB  2021-01-15              5135.0
# ...                ...      ...         ...                 ...
# 1019   Northern Cyprus      NaN  2021-01-19              4968.0
# 1662             Wales      NaN  2021-01-14            126504.0
# 1620     United States      USA  2021-01-18                 NaN
# 1309          Scotland      NaN  2021-01-16                 NaN
# 1048  Northern Ireland      NaN  2021-01-07                 NaN
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 582              2501.0                      NaN                  1056.0
# ...

# %%
most_vaccinated_people=df.groupby('country').total_vaccinations.max().sort_values(ascending=False)
most_vaccinated_people
# Out:
# country
# United States     24652634.0
# China             22767000.0
# United Kingdom     7923497.0
# England            6918853.0
# Israel             4347206.0
#                      ...
# Isle of Man           6281.0
# Myanmar               3800.0
# Ecuador               2982.0
# Bermuda               2932.0
# Kuwait                2500.0
# Name: total_vaccinations, Length: 63, dtype: float64

# %%
df.date=pd.to_datetime(df.date)

# %%
df=pd.pivot_table(data=df,index=pd.Grouper(key='date',freq='M'),columns='country',aggfunc='max')
df.iloc[:3]['daily_vaccinations']
# Out:
# country     Algeria  Andorra  Argentina  Austria  Bahrain  Bangladesh  \
# date
# 2020-12-31      NaN      NaN    15656.0      NaN  11106.0         NaN
# 2021-01-31     30.0     66.0    14788.0  15156.0   7572.0      1949.0
# 2021-02-28      NaN     66.0    19390.0  10056.0   5552.0      3059.0
#
# country     Belgium  Bermuda  Bolivia    Brazil  ...  Slovenia    Spain  \
# date                                             ...
# 2020-12-31    240.0      NaN      NaN       NaN  ...    1546.0      NaN
# 2021-01-31  16922.0    281.0     22.0  209905.0  ...    2655.0  70264.0
# 2021-02-28  16400.0      NaN    593.0  231737.0  ...    2742.0  73424.0
#
# country     Sri Lanka   Sweden  Switzerland    Turkey  United Arab Emirates  \
# date
# 2020-12-31        NaN   1711.0       3000.0       NaN                   NaN
# 2021-01-31    19718.0  14685.0      16809.0  308326.0              120910.0
# 2021-02-28    23888.0  14210.0      18865.0  119078.0              155311.0
#
# ...
